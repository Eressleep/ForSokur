# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model  import LinearRegression

# %%
train       = pd.read_csv('train.csv')
test        = pd.read_csv('test.csv')
feature     = ['x1', 'x2', 'x3', 'x4', 'x5']
test_x      = test[feature]
poly_test_x = PolynomialFeatures(degree=5).fit_transform(test_x)
train_x     = train[feature]
train_y     = train['y']

train
# Out:
#           id  x1  x2  x3  x4  x5           y
# 0          0   1   9   8   2   6  332.773904
# 1          1   0   8   0   2   7  298.091343
# 2          2   9   1   1   4   2  761.100225
# 3          3   7   9   2   8   6  686.106507
# 4          4   2   0   0   1   0   13.357220
# ...      ...  ..  ..  ..  ..  ..         ...
# 79995  79995   6   4   1   1   4  304.940199
# 79996  79996   7   8   9   1   4  567.954361
# 79997  79997   6   5   0   8   1  301.367582
# 79998  79998   4   8   0   7   2  227.354170
# 79999  79999   0   8   3   9   6  310.713898
#
# [80000 rows x 7 columns]

# %%
poly_reg = PolynomialFeatures(degree=5)
x_poly   = poly_reg.fit_transform(train_x)

poly_reg = LinearRegression()
model    = poly_reg.fit(x_poly, train_y)
prediction = model.predict(poly_test_x)

prediction
# Out:
# array([ 43.48889924, 605.52418287,  90.51699561, ...,  88.50350283,
#        199.50566792, 500.49899919])

# %%
output = pd.DataFrame({'id': test.id,'y': prediction})
output.to_csv('submission.csv', index=False)
